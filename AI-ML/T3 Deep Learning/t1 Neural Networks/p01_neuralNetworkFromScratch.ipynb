# %% [markdown]
# ##### Building a Neural Network from Scratch: Implement feedforward and backpropagation in NumPy

# %%
import numpy as np

# %%
X = np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
])

y = np.array([
    [0],
    [1],
    [1],
    [0]
])

# %%
print(X.shape)
print(y.shape)
# Out:
# (4, 2)
# (4, 1)

# %%
W1 = np.random.rand(2,2)

print(W1)
# Out:
# [[0.90990311 0.25573762]
#  [0.88435478 0.11400726]]

# %%
b1 = np.random.rand(1,2)

print(b1)
# Out:
# [[0.40372856 0.62493194]]

# %%
x = X[0]

print(x)
# Out:
# [0 0]

# %%
z1 = np.dot(x, W1) + b1

print(z)
# Out:
# [[0.40372856 0.62493194]]

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
a1 = sigmoid(z1)

# %%
W2 = np.random.rand(2,1)
b2 = np.random.rand(1,1)

# %%
z2 = np.dot(a1, W2) + b2

# %%
a2 = sigmoid(z2)

# %%
z1 = np.dot(X, W1) + b1
a1 = sigmoid(z1)

z2 = np.dot(a1, W2) + b2
a2 = sigmoid(z2)

# %%
loss = np.mean((y - a2) ** 2)

print(loss)
# Out:
# 0.3238730495268777

# %%
error = y - a2

# %%
a = sigmoid(x)

# %%
def sigmoid_derivative(a):
    return a * (1 - a)

# %%
delta2 = (a2 - y) * sigmoid_derivative(a2)

# %%
dW2 = np.dot(a1.T, delta2)

# %%
db2 = np.sum(delta2, axis=0, keepdims=True)

# %%
delta1 = np.dot(delta2, W2.T) * sigmoid_derivative(a1)

# %%
dW1 = np.dot(X.T, delta1)

db1 = np.sum(delta1, axis=0, keepdims=True)

# %%
learning_rate = 0.1

# %%
W2 -= learning_rate * dW2
b2 -= learning_rate * db2

W1 -= learning_rate * dW1
b1 -= learning_rate * db1

# %%
for epoch in range(10000):

    # Feedforward

    z1 = np.dot(X, W1) + b1
    a1 = sigmoid(z1)

    z2 = np.dot(a1, W2) + b2
    a2 = sigmoid(z2)

    # Loss

    loss = np.mean((y - a2) ** 2)

    # Backpropagation

    delta2 = (a2 - y) * sigmoid_derivative(a2)

    dW2 = np.dot(a1.T, delta2)
    db2 = np.sum(delta2, axis=0, keepdims=True)

    delta1 = np.dot(delta2, W2.T) * sigmoid_derivative(a1)

    dW1 = np.dot(X.T, delta1)
    db1 = np.sum(delta1, axis=0, keepdims=True)

    # Update

    W2 -= learning_rate * dW2
    b2 -= learning_rate * db2

    W1 -= learning_rate * dW1
    b1 -= learning_rate * db1

# %%
print(a2)
# Out:
# [[0.05413915]
#  [0.95067065]
#  [0.95080694]
#  [0.05292452]]
