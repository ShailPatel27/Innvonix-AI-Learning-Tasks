# %% [markdown]
# Description
#
# Description: Master Python as it's the primary language for AI/ML development.
#
# Topics to Cover:
# - Variables, data types, operators
# - Control structures (if/else, loops)
# - Functions and lambda expressions
# - Object-Oriented Programming
# - File handling and exceptions
# - List comprehensions and generators
#
# Hands-on Exercise:
# - Build a contact management system with CRUD operations
# - Create a text-based game (e.g., Tic-Tac-Toe) using OOP principles
# - Develop a file parser that reads CSV/JSON and generates reports

# %% [markdown]
# ### Contact Management

# %%
# %run p02_contactManagementSystem.py

# %% [markdown]
# ### Tictactoe

# %%
# %run p01_OOP_Tictactoe.py

# %% [markdown]
# ### File Parser

# %%
# %run p03_fileParser.py
