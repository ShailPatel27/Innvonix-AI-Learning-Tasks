# %% [markdown]
# ## Advanced Topics and Integration

# %% [markdown]
# Description
#
# Task: Explore types of exceptions and implement exception handling.
#
# Task: Learn about logging in Python and implement basic logging in a script.
#
# Task: Understand events and implement EventMethods..
#
# Task: Introduce the 'with' statement and its use in file handling.

# %% [markdown]
# ### Types of Exceptions

# %%
try:
    num = 10 / 0

except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %%
try:
    a = [10, 20, 30]
    print(a[5])
    
except IndexError:
    print("List index out of bounds")
# Out:
# List index out of bounds

# %% [markdown]
# ### Logging

# %%
import logging

logging.basicConfig(level=logging.INFO)

logging.info("Program started")
logging.warning("This is a warning")
logging.error("An error occurred")
# Out:
# INFO:root:Program started
# WARNING:root:This is a warning
# ERROR:root:An error occurred

# %% [markdown]
# ### Events

# %%
from threading import Event
import threading
import time


event = Event()


def task():
    print("Waiting...")

    event.wait()

    print("Event received")


threading.Thread(target=task).start()

time.sleep(2)

event.set()
# Out:
# Waiting...
# Event received

# %% [markdown]
# ### With

# %%
with open("p06.txt", "w") as file:
    file.write("Hello World")
