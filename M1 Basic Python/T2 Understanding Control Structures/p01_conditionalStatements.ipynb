# %% [markdown]
# ## Conditional Statements

# %% [markdown]
# Description: Conditional statements allow you to execute certain blocks of code based on specific conditions. The if statement evaluates a condition and executes the associated block of code if the condition is true. The elif and else statements provide additional conditions and a default action if no conditions are met.
#
# Challenge:
#
# 1. Write a function grade_classifier that takes a score as an argument.
# 2. Use conditional statements to classify the score into "A", "B", "C", "D", or "F".
# 3. Print the grade based on the score.

# %%
def grade_classifier(score):
    if score >= 90:
        grade = "A"
    elif score >= 80:
        grade = "B"
    elif score >= 70:
        grade = "C"
    elif score >= 60:
        grade = "D"
    else:
        grade = "F"

    print(f"Score: {score} | Grade: {grade}")

# %%
grade_classifier(95)
grade_classifier(40)
grade_classifier(82)
# Out:
# Score: 95 | Grade: A
# Score: 40 | Grade: F
# Score: 82 | Grade: B
