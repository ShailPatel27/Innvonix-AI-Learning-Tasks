# %% [markdown]
# ## Class Methods

# %% [markdown]
# Description: Class methods take a cls parameter, which refers to the class itself, not the instance. They are defined using the @classmethod decorator and can be used to access or modify the class state.
#
# Challenge:
#
# 1. Define a class Library with a class attribute total_books.
# 2. Create a class method update_total_books that updates the total_books attribute.
# 3. Call the class method to modify the class attribute.

# %%
# Define class
class Library:

    # Class attribute
    total_books = 0

    # Class method
    @classmethod
    def update_total_books(cls, count):
        cls.total_books = count


# Call class method
Library.update_total_books(500)

print(Library.total_books)
# Out:
# 500
