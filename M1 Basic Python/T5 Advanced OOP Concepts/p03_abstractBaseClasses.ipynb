# %% [markdown]
# ## Abstract Base Classes

# %% [markdown]
# Description: Define an abstract base class with abstract methods that must be implemented by subclasses.
#
# Task: Create an abstract base class Shape with abstract methods area() and perimeter(), and implement concrete subclasses Circle and Rectangle.

# %% [markdown]
# Methods of abstract classes have to be the same for all the classes that inherit an abstract class.

# %%
from abc import ABC, abstractmethod
import math
# ABC is an inbuilt class that defines that the following class is abstract when inherited.

# %% [markdown]
# ### Abstract Base Class

# %%
class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimeter(self):
        pass

# %% [markdown]
# ### Circle Class

# %%
class Circle(Shape):

    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.radius

# %% [markdown]
# ### Rectangle class

# %%
class Rectangle(Shape):

    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

    def perimeter(self):
        return 2 * (self.length + self.width)

# %% [markdown]
# ### Testing

# %%
c = Circle(5)
r = Rectangle(4, 6)

print(c.area())
print(c.perimeter())

print(r.area())
print(r.perimeter())
# Out:
# 78.53981633974483
# 31.41592653589793
# 24
# 20
