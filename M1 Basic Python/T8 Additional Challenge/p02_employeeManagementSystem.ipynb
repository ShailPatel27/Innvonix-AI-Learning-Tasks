# %% [markdown]
# ## Employee Management System

# %% [markdown]
# Objective: Create a simple employee management system that allows adding new employees, calculating average salary, and displaying employee details.
#
# Class Method - Add Employee: Use a class method to add new employees to a class-level list. Each employee should have a unique ID, name, and salary.
#
# Static Method - Average Salary: Implement a static method to calculate the average salary of all employees. This method should work without needing to instantiate the class.
#
# Instance Method - Display Details: Define an instance method to display an employee’s details. It should print the employee’s ID, name, and salary.

# %% [markdown]
# ### Employee class

# %%
class Employee:

    employees = []   # Class-level list

    def __init__(self, emp_id, name, salary):
        self.emp_id = emp_id
        self.name = name
        self.salary = salary

    # Class method
    @classmethod
    def add_employee(cls, emp_id, name, salary):
        employee = cls(emp_id, name, salary)
        cls.employees.append(employee)

    # Static method
    @staticmethod
    def average_salary(employee_list):
        total = 0

        for emp in employee_list:
            total += emp.salary

        return total / len(employee_list)

    # Instance method
    def display_details(self):
        print("ID:", self.emp_id)
        print("Name:", self.name)
        print("Salary:", self.salary)

# %% [markdown]
# ### Objects and Methods

# %%
# Add employees
Employee.add_employee(1, "Shail", 50000)
Employee.add_employee(2, "Raj", 60000)

# Display employee details
for emp in Employee.employees:
    emp.display_details()
    print()

# Calculate average salary
avg = Employee.average_salary(Employee.employees)

print("Average Salary:", avg)
# Out:
# ID: 1
# Name: Shail
# Salary: 50000
#
# ID: 2
# Name: Raj
# Salary: 60000
#
# Average Salary: 55000.0
