# %% [markdown]
# ## Functions

# %% [markdown]
# Description: Functions are blocks of reusable code that perform a specific task. They are defined using the def keyword.
#
# Challenge:
#
# 1. Define a function greet that takes a name as an argument and prints a greeting message.
# 2. Define a function calculate_area that takes length and width as arguments and returns the area of a rectangle.

# %%
def greet(name):
    print(f"Hello {name}")
    
greet("Shail")

# %%
def calculate_area(length, width):
    return length*width

print(f"Area of square of Length 20 and Width 30 is {calculate_area(20, 30)}")
